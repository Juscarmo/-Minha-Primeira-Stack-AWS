# %% [markdown]
# <a href="https://colab.research.google.com/github/Juscarmo/-Minha-Primeira-Stack-AWS/blob/main/Curso_Python_FIAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
